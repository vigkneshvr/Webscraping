# %%
import requests
from bs4 import BeautifulSoup
import shutil
import os
import pandas as pd

# %%
url = "https://books.toscrape.com/"

response = requests.get(url)

if response.status_code==200:
    print("Request succesful")
else:
    print("Request failed")
# Out:
# Request succesful

# %%
soup= BeautifulSoup(response.text, "html.parser") # Parse HTML
category_links = []
category_name= []
for link in soup.find_all("a", href=True):
    if link["href"].startswith("catalogue/category/"):
        category_links.append(link["href"])

for name in category_links:
    n= name.split("/")[3]
    n=n.split("_")[0]
    category_name.append(n)

category_name=category_name[1:]
category_links=category_links[1:]

# %%
books_data=[]

for catgeory_index,category_link in enumerate(category_links):
    page_index=1
    image_directory= f"images/{category_name[catgeory_index]}"
    os.makedirs(image_directory, exist_ok=True)
    book_number=1
    while(True):
        if page_index>1:
            modified_link= category_link.split("/")
            modified_link[-1]= f"page-{page_index}.html"
            modified_link=  "/".join(modified_link)
            link= url+modified_link
        else:
            link= url+category_link

        book_response= requests.get(link)
        book_response_status= book_response.status_code
        if(book_response_status!=200):
            break
        
        book_soup= BeautifulSoup(book_response.text, "html.parser")
        books = book_soup.find_all("article", class_="product_pod")
        book_images= book_soup.findAll('img')
        for image in book_images:
            i= image["src"].replace("../../../../","")
            image_link= url+i
            r = requests.get(image_link, stream=True)
            if r.status_code == 200:                     #200 status code = OK
                with open(f"images/{category_name[catgeory_index]}/book_{book_number}.jpg", 'wb') as f: 
                    r.raw.decode_content = True
                    shutil.copyfileobj(r.raw, f)
                    book_number+=1

        for book in books:
            title = book.h3.a["title"]
            price = book.find("p", class_="price_color").get_text().strip()
            rating = book.p["class"][1]
            stock = book.find("p", class_="instock availability").get_text().strip()
            category= category_link.split("/")[3].split("_")[0]

            books_data.append([title, price, rating, category, stock])
  
        page_index+=1

df= pd.DataFrame(books_data, columns=["title", "price", "rating", "category", "stock"])
df.to_csv("scraped_books.csv")

# %%
print(books_data)
# Out:
# [["It's Only the Himalayas", 'Â£45.17', 'Two', 'travel', 'In stock'], ['Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond', 'Â£49.43', 'Four', 'travel', 'In stock'], ['See America: A Celebration of Our National Parks & Treasured Sites', 'Â£48.87', 'Three', 'travel', 'In stock'], ['Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', 'Â£36.94', 'Two', 'travel', 'In stock'], ['Under the Tuscan Sun', 'Â£37.33', 'Three', 'travel', 'In stock'], ['A Summer In Europe', 'Â£44.34', 'Two', 'travel', 'In stock'], ['The Great Railway Bazaar', 'Â£30.54', 'One', 'travel', 'In stock'], ['A Year in Provence (Provence #1)', 'Â£56.88', 'Four', 'travel', 'In stock'], ['The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)', 'Â£23.21', 'One', 'travel', 'In stock'], ['Neither Here nor There: Travels in Europe', 'Â£38.95', 'Three', 'travel', 'In stock'], ['1,000 Places to See Before You Die', 'Â£26.08', 'Five', 'travel', 'In stock'], ['Sharp Objects', 'Â£47.82', 'Four', 'mystery', 'In stock'], ['In a Dark, Dark Wood', 'Â£19.63', 'One', 'mystery', 'In stock'], ['The Past Never Ends', 'Â£56.50', 'Four', 'mystery', 'In stock'], ['A Murder in Time', 'Â£16.64', 'One', 'mystery', 'In stock'], ['The Murder of Roger Ackroyd (Hercule Poirot #4)', 'Â£44.10', 'Four', 'mystery', 'In stock'], ['The Last Mile (Amos Decker #2)', 'Â£54.21', 'Two', 'mystery', 'In stock'], ['That Darkness (Gardiner and Renner #1)', 'Â£13.92', 'One', 'mystery', 'In stock'], ['Tastes Like Fear (DI Marnie Rome #3)', 'Â£10.69', 'One', 'mystery', 'In stock'], ['A Time of Torment (Charlie Parker #14)', 'Â£48.35', 'Five', 'mystery', 'In stock'], ['A Study in Scarlet (Sherlock Holmes #1)', 'Â£16.73', 'Two', 'mystery', 'In stock'], ['Poisonous (Max Revere Novels #3)', 'Â£26.80', 'Three', 'mystery', 'In stock'], ['Murder at the 42nd Street Library (Raymond Ambler #1)', 'Â£54.36', 'Four', 'mystery', 'In stock'], ['Most Wanted', 'Â£35.28', 'Three', 'mystery', 'In stock'], ['Hide Away (Eve Duncan #20)', 'Â£11.84', 'One', 'mystery', 'In stock'], ['Boar Island (Anna Pigeon #19)', 'Â£59.48', 'Three', 'mystery', 'In stock'], ['The Widow', 'Â£27.26', 'Two', 'mystery', 'In stock'], ['Playing with Fire', 'Â£13.71', 'Three', 'mystery', 'In stock'], ['What Happened on Beale Street (Secrets of the South Mysteries #2)', 'Â£25.37', 'Five', 'mystery', 'In stock'], ["The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", 'Â£52.30', 'Five', 'mystery', 'In stock'], ['Delivering the Truth (Quaker Midwife Mystery #1)', 'Â£20.89', 'Four', 'mystery', 'In stock'], ['The Mysterious Affair at Styles (Hercule Poirot #1)', 'Â£24.80', 'Four', 'mystery', 'In stock'], ['In the Woods (Dublin Murder Squad #1)', 'Â£38.38', 'Two', 'mystery', 'In stock'], ['The Silkworm (Cormoran Strike #2)', 'Â£23.05', 'Five', 'mystery', 'In stock'], ['The Exiled', 'Â£43.45', 'Three', 'mystery', 'In stock'], ["The Cuckoo's Calling (Cormoran Strike #1)", 'Â£19.21', 'One', 'mystery', 'In stock'], ['Extreme Prey (Lucas Davenport #26)', 'Â£25.40', 'Three', 'mystery', 'In stock'], ['Career of Evil (Cormoran Strike #3)', 'Â£24.72', 'Two', 'mystery', 'In stock'], ["The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", 'Â£57.70', 'Four', 'mystery', 'In stock'], ['The Girl You Lost', 'Â£12.29', 'Five', 'mystery', 'In stock'], ['The Girl In The Ice (DCI Erika Foster #1)', 'Â£15.85', 'Three', 'mystery', 'In stock'], ['Blood Defense (Samantha Brinkman #1)', 'Â£20.30', 'Three', 'mystery', 'In stock'], ["1st to Die (Women's Murder Club #1)", 'Â£53.98', 'One', 'mystery', 'In stock'], ['Tipping the Velvet', 'Â£53.74', 'One', 'historical-fiction', 'In stock'], ['Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'Â£29.69', 'Three', 'historical-fiction', 'In stock'], ['A Flight of Arrows (The Pathfinders #2)', 'Â£55.53', 'Five', 'historical-fiction', 'In stock'], ['The House by the Lake', 'Â£36.95', 'One', 'historic ...
